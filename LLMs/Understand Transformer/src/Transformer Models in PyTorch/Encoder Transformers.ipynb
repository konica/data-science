# %% [markdown]
# ## The original transformer
# ![{AB06A9D6-7947-40DE-9AE8-3DDE0DC75CDB}.png](attachment:{AB06A9D6-7947-40DE-9AE8-3DDE0DC75CDB}.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# # Encoder-only transformer
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Feed-forward sublayer in encoder layers
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Encoder layer
# Input sentences/query has the different length (about number of tokens). To make them have the same length, we often add padding tokens. However, during the attention process, we need to remove their impact from the relationship between token. That's why we need a mask to filter out the padding tokens.
#
# ![image.png](attachment:image.png)
